# %%
import csv
import pandas as pd
# Out:
# C:\Users\anabi\AppData\Roaming\Python\Python37\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
reviews = pd.read_csv("F:\\Dealer_Reviews\\reviews.csv", sep=";")
dealers = pd.read_csv("F:\\Dealer_Reviews\\dealers.csv", sep=";")
cars = pd.read_csv("F:\\Dealer_Reviews\\cars.csv", sep=";")

# %%
reviews
# Out:
#                                    dealer_id  review_score  \
# 0       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 1       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 2       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 3       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 4       924b6a44-24bb-4640-844d-2ace5ea8f188           2.0
# ...                                      ...           ...
# 371647  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371648  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371649  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371650  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371651  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
#
#                                              review_title        review_date  \
# 0       Good place to do business with, friendly, cour...  February 15, 2023
# 1                                          Happy Customer  February 14, 2023
# ...

# %%
reviews['dealer_id'].nunique()
# Out:
# 1031

# %% [markdown]
# There are 244 dealers without reviews

# %%
cars
# Out:
#                                    dealer_id  \
# 0       924b6a44-24bb-4640-844d-2ace5ea8f188
# 1       924b6a44-24bb-4640-844d-2ace5ea8f188
# 2       924b6a44-24bb-4640-844d-2ace5ea8f188
# 3       924b6a44-24bb-4640-844d-2ace5ea8f188
# 4       924b6a44-24bb-4640-844d-2ace5ea8f188
# ...                                      ...
# 152985  593465de-0226-4a67-8d89-320ae6bee4f6
# 152986  593465de-0226-4a67-8d89-320ae6bee4f6
# 152987  593465de-0226-4a67-8d89-320ae6bee4f6
# 152988  593465de-0226-4a67-8d89-320ae6bee4f6
# 152989  593465de-0226-4a67-8d89-320ae6bee4f6
#
#                                                  title   mileage       price
# 0                                2018 BMW X5 xDrive50i   87889.0     $33,891
# 1                               2015 Nissan Frontier S  114543.0     $12,941
# 2                     2014 Chevrolet Suburban 1500 LTZ  102963.0     $20,891
# 3                        2023 Kia Sportage SX-Prestige       NaN     $34,750
# ...

# %%
cars['dealer_id'].nunique()
# Out:
# 1170

# %% [markdown]
# There are 105 dealers without inventory

# %%
dealers
# Out:
#                                  dealer_id state  \
# 0     924b6a44-24bb-4640-844d-2ace5ea8f188    AL
# 1     2a33eed9-0196-4ac5-aff3-79eb735f5a61    AL
# 2     90ff669f-0e23-473b-90a3-a832dc81241e    AL
# 3     7612b686-6f9f-4238-a179-895288cf8489    AL
# 4     0d5e993b-d4b3-4abb-95f2-9bfed37d6714    AL
# ...                                    ...   ...
# 1270  0d450a37-49df-4729-b9c0-1c539e7cb83a    WY
# 1271  37d226eb-d023-4a7f-98aa-e128ba7328a0    WY
# 1272  7ee4f60a-8953-490c-a0af-26b11ed5fd55    WY
# 1273  a41ba20d-9a4d-43a4-ba79-555e1033890c    WY
# 1274  593465de-0226-4a67-8d89-320ae6bee4f6    WY
#
#                                             dealer_link avg_rating  \
# 0     https://www.cars.com/dealers/5371939/serra-tru...        4.3
# 1     https://www.cars.com/dealers/5390798/serra-hyu...        4.8
# 2     https://www.cars.com/dealers/148992/courtesy-b...  Not rated
# 3     https://www.cars.com/dealers/5366741/benchmark...        4.7
# ...

# %%
dealers['dealer_id'].nunique()
# Out:
# 1275

# %%
dealers[dealers['state'] == "AL"]
# Out:
#                                dealer_id state  \
# 0   924b6a44-24bb-4640-844d-2ace5ea8f188    AL
# 1   2a33eed9-0196-4ac5-aff3-79eb735f5a61    AL
# 2   90ff669f-0e23-473b-90a3-a832dc81241e    AL
# 3   7612b686-6f9f-4238-a179-895288cf8489    AL
# 4   0d5e993b-d4b3-4abb-95f2-9bfed37d6714    AL
# 5   d463f1f8-cda1-4470-aca9-4b7385bb7500    AL
# 6   82d0a756-fc41-44d9-95ee-c7009dff06f7    AL
# 7   e18d4e83-f0d0-4e15-ad05-ef0da5ee8005    AL
# 8   d7470c23-846f-42e5-9954-0111f9e19719    AL
# 9   f4358884-caa1-40a3-ae54-b5b7fc7f535e    AL
# 10  a32e09b8-f916-4450-a216-2648a5828b8e    AL
# 11  7d409250-4821-48ab-aea3-f802d8323f25    AL
# 12  b64c80c5-51f2-4300-98d0-f0d72fc6323e    AL
# 13  5b69a5b5-0c47-45d4-b003-72642f93eb49    AL
# 14  0adaeffa-70bc-4c29-8109-a68fc457e67a    AL
# 15  eb35c449-8b16-42b7-9b41-9884a80936c3    AL
# 16  dffd3e7b-e885-4f21-90fe-19fbef6acbee    AL
# 17  b7cd04de-bf58-4cce-be97-5ee63ab7dafd    AL
# 18  6430671b-ad51-49c9-88e2-cc57cd003f3d    AL
# ...

# %%
dealers[:25]
# Out:
#                                dealer_id state  \
# 0   924b6a44-24bb-4640-844d-2ace5ea8f188    AL
# 1   2a33eed9-0196-4ac5-aff3-79eb735f5a61    AL
# 2   90ff669f-0e23-473b-90a3-a832dc81241e    AL
# 3   7612b686-6f9f-4238-a179-895288cf8489    AL
# 4   0d5e993b-d4b3-4abb-95f2-9bfed37d6714    AL
# 5   d463f1f8-cda1-4470-aca9-4b7385bb7500    AL
# 6   82d0a756-fc41-44d9-95ee-c7009dff06f7    AL
# 7   e18d4e83-f0d0-4e15-ad05-ef0da5ee8005    AL
# 8   d7470c23-846f-42e5-9954-0111f9e19719    AL
# 9   f4358884-caa1-40a3-ae54-b5b7fc7f535e    AL
# 10  a32e09b8-f916-4450-a216-2648a5828b8e    AL
# 11  7d409250-4821-48ab-aea3-f802d8323f25    AL
# 12  b64c80c5-51f2-4300-98d0-f0d72fc6323e    AL
# 13  5b69a5b5-0c47-45d4-b003-72642f93eb49    AL
# 14  0adaeffa-70bc-4c29-8109-a68fc457e67a    AL
# 15  eb35c449-8b16-42b7-9b41-9884a80936c3    AL
# 16  dffd3e7b-e885-4f21-90fe-19fbef6acbee    AL
# 17  b7cd04de-bf58-4cce-be97-5ee63ab7dafd    AL
# 18  6430671b-ad51-49c9-88e2-cc57cd003f3d    AL
# ...

# %%
dealers = dealers.drop(range(25,50))

# %%
dealers[:26]
# Out:
#                                dealer_id state  \
# 0   924b6a44-24bb-4640-844d-2ace5ea8f188    AL
# 1   2a33eed9-0196-4ac5-aff3-79eb735f5a61    AL
# 2   90ff669f-0e23-473b-90a3-a832dc81241e    AL
# 3   7612b686-6f9f-4238-a179-895288cf8489    AL
# 4   0d5e993b-d4b3-4abb-95f2-9bfed37d6714    AL
# 5   d463f1f8-cda1-4470-aca9-4b7385bb7500    AL
# 6   82d0a756-fc41-44d9-95ee-c7009dff06f7    AL
# 7   e18d4e83-f0d0-4e15-ad05-ef0da5ee8005    AL
# 8   d7470c23-846f-42e5-9954-0111f9e19719    AL
# 9   f4358884-caa1-40a3-ae54-b5b7fc7f535e    AL
# 10  a32e09b8-f916-4450-a216-2648a5828b8e    AL
# 11  7d409250-4821-48ab-aea3-f802d8323f25    AL
# 12  b64c80c5-51f2-4300-98d0-f0d72fc6323e    AL
# 13  5b69a5b5-0c47-45d4-b003-72642f93eb49    AL
# 14  0adaeffa-70bc-4c29-8109-a68fc457e67a    AL
# 15  eb35c449-8b16-42b7-9b41-9884a80936c3    AL
# 16  dffd3e7b-e885-4f21-90fe-19fbef6acbee    AL
# 17  b7cd04de-bf58-4cce-be97-5ee63ab7dafd    AL
# 18  6430671b-ad51-49c9-88e2-cc57cd003f3d    AL
# ...

# %%
dealers = dealers.reset_index()
dealers = dealers.drop("index", axis = 1)

# %%
#dealers = dealers.drop("level_0", axis = 1)

# %%
dealers
# Out:
#                                  dealer_id state  \
# 0     924b6a44-24bb-4640-844d-2ace5ea8f188    AL
# 1     2a33eed9-0196-4ac5-aff3-79eb735f5a61    AL
# 2     90ff669f-0e23-473b-90a3-a832dc81241e    AL
# 3     7612b686-6f9f-4238-a179-895288cf8489    AL
# 4     0d5e993b-d4b3-4abb-95f2-9bfed37d6714    AL
# ...                                    ...   ...
# 1245  0d450a37-49df-4729-b9c0-1c539e7cb83a    WY
# 1246  37d226eb-d023-4a7f-98aa-e128ba7328a0    WY
# 1247  7ee4f60a-8953-490c-a0af-26b11ed5fd55    WY
# 1248  a41ba20d-9a4d-43a4-ba79-555e1033890c    WY
# 1249  593465de-0226-4a67-8d89-320ae6bee4f6    WY
#
#                                             dealer_link avg_rating  \
# 0     https://www.cars.com/dealers/5371939/serra-tru...        4.3
# 1     https://www.cars.com/dealers/5390798/serra-hyu...        4.8
# 2     https://www.cars.com/dealers/148992/courtesy-b...  Not rated
# 3     https://www.cars.com/dealers/5366741/benchmark...        4.7
# ...

# %%
dealers['state'].nunique()
# Out:
# 50

# %%
dealers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dealer_id          1250 non-null   object
#  1   state              1250 non-null   object
#  2   dealer_link        1250 non-null   object
#  3   avg_rating         1250 non-null   object
#  4   nr_reviews         1104 non-null   float64
#  5   inventory_size     1146 non-null   Int64
#  6   inventory_link     1146 non-null   object
#  7   registration_date  1090 non-null   object
# dtypes: Int64(1), float64(1), object(6)
# memory usage: 79.5+ KB

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152990 entries, 0 to 152989
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   dealer_id  152990 non-null  object
#  1   title      152990 non-null  object
#  2   mileage    84329 non-null   float64
#  3   price      152990 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 4.7+ MB

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371652 entries, 0 to 371651
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   dealer_id       371652 non-null  object
#  1   review_score    371652 non-null  float64
#  2   review_title    371645 non-null  object
#  3   review_date     371652 non-null  object
#  4   review_text     371652 non-null  object
#  5   cust_service    371652 non-null  object
#  6   buying_process  371652 non-null  object
#  7   repair_quality  371652 non-null  object
#  8   facilities      371652 non-null  object
#  9   experience      371652 non-null  object
#  10  recommend       371652 non-null  object
#  11  purchase_type   371652 non-null  object
#  12  purchase        371652 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 36.9+ MB

# %%
dealers['inventory_size'] = dealers['inventory_size'].astype('Int64')

# %%
dealers['nr_reviews'] = dealers['nr_reviews'].astype('Int64')

# %% [raw]
# for i in range(len(dealers)):
#     if dealers['avg_rating'][i] == 'Not rated':
#         dealers['avg_rating'][i] = float("NaN")

# %%
dealers['avg_rating'].loc[dealers['avg_rating'] == "Not rated"] = float("NaN")
# Out:
# C:\Users\anabi\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
dealers
# Out:
#                                  dealer_id state  \
# 0     924b6a44-24bb-4640-844d-2ace5ea8f188    AL
# 1     2a33eed9-0196-4ac5-aff3-79eb735f5a61    AL
# 2     90ff669f-0e23-473b-90a3-a832dc81241e    AL
# 3     7612b686-6f9f-4238-a179-895288cf8489    AL
# 4     0d5e993b-d4b3-4abb-95f2-9bfed37d6714    AL
# ...                                    ...   ...
# 1245  0d450a37-49df-4729-b9c0-1c539e7cb83a    WY
# 1246  37d226eb-d023-4a7f-98aa-e128ba7328a0    WY
# 1247  7ee4f60a-8953-490c-a0af-26b11ed5fd55    WY
# 1248  a41ba20d-9a4d-43a4-ba79-555e1033890c    WY
# 1249  593465de-0226-4a67-8d89-320ae6bee4f6    WY
#
#                                             dealer_link avg_rating  \
# 0     https://www.cars.com/dealers/5371939/serra-tru...        4.3
# 1     https://www.cars.com/dealers/5390798/serra-hyu...        4.8
# 2     https://www.cars.com/dealers/148992/courtesy-b...        NaN
# 3     https://www.cars.com/dealers/5366741/benchmark...        4.7
# ...

# %%
dealers['avg_rating'] = dealers['avg_rating'].astype('float')

# %%
dealers['state'] = dealers['state'].astype('str')
dealers['dealer_link'] = dealers['dealer_link'].astype('str')
dealers['inventory_link'] = dealers['inventory_link'].astype('str')

# %%
dealers['registration_date'] = dealers['registration_date'].astype('str')

# %%
dealers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dealer_id          1250 non-null   object
#  1   state              1250 non-null   object
#  2   dealer_link        1250 non-null   object
#  3   avg_rating         742 non-null    float64
#  4   nr_reviews         1104 non-null   Int64
#  5   inventory_size     1146 non-null   Int64
#  6   inventory_link     1250 non-null   object
#  7   registration_date  1090 non-null   object
# dtypes: Int64(2), float64(1), object(5)
# memory usage: 80.7+ KB

# %%
from datetime import datetime

# %%
dealers['registration_date'] = pd.to_datetime(dealers['registration_date'], infer_datetime_format=True)

# %%
#dealers['registration_date'] = dealers['registration_date'].dt.strftime('%Y-%m')

# %%
#dealers['registration_date'] = pd.to_datetime(dealers['registration_date'], format="%Y-%m")

# %%
dealers['registration_date']
# Out:
# 0      2017-02-01
# 1      2019-11-01
# 2      2014-08-01
# 3             NaT
# 4      2008-02-01
#           ...
# 1245   2020-03-01
# 1246   2020-01-01
# 1247   2020-12-01
# 1248   2022-03-01
# 1249   2013-06-01
# Name: registration_date, Length: 1250, dtype: datetime64[ns]

# %%
dealers['registration_date'].sort_values()
# Out:
# 516    1999-01-01
# 186    1999-05-01
# 63     1999-06-01
# 67     1999-06-01
# 61     1999-08-01
#           ...
# 1230          NaT
# 1232          NaT
# 1233          NaT
# 1242          NaT
# 1243          NaT
# Name: registration_date, Length: 1250, dtype: datetime64[ns]

# %%
dates = dealers['registration_date'].dropna()

# %%
dates
# Out:
# 0      2017-02-01
# 1      2019-11-01
# 2      2014-08-01
# 4      2008-02-01
# 5      2013-10-01
#           ...
# 1245   2020-03-01
# 1246   2020-01-01
# 1247   2020-12-01
# 1248   2022-03-01
# 1249   2013-06-01
# Name: registration_date, Length: 1090, dtype: datetime64[ns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1,figsize =(10, 7))
ax.hist(dates, bins = 60, color = "orange", ec="blue")
ax.grid(True)
ax.set_title("Distribution of published videos over years")
ax.set_xlabel("Publishing year")
ax.set_ylabel("Video frequency")
# Out:
# Text(0, 0.5, 'Video frequency')

# %%
cars['mileage'] = cars['mileage'].astype('Int64')

# %%
cars
# Out:
#                                    dealer_id  \
# 0       924b6a44-24bb-4640-844d-2ace5ea8f188
# 1       924b6a44-24bb-4640-844d-2ace5ea8f188
# 2       924b6a44-24bb-4640-844d-2ace5ea8f188
# 3       924b6a44-24bb-4640-844d-2ace5ea8f188
# 4       924b6a44-24bb-4640-844d-2ace5ea8f188
# ...                                      ...
# 152985  593465de-0226-4a67-8d89-320ae6bee4f6
# 152986  593465de-0226-4a67-8d89-320ae6bee4f6
# 152987  593465de-0226-4a67-8d89-320ae6bee4f6
# 152988  593465de-0226-4a67-8d89-320ae6bee4f6
# 152989  593465de-0226-4a67-8d89-320ae6bee4f6
#
#                                                  title  mileage       price
# 0                                2018 BMW X5 xDrive50i    87889     $33,891
# 1                               2015 Nissan Frontier S   114543     $12,941
# 2                     2014 Chevrolet Suburban 1500 LTZ   102963     $20,891
# 3                        2023 Kia Sportage SX-Prestige     <NA>     $34,750
# ...

# %% [raw]
# for i in range(len(cars)):
#     cars['price'][i] = cars['price'][i][1:]

# %%
cars['price'] = cars['price'].apply(lambda x: x[1:])

# %%
cars
# Out:
#                                    dealer_id  \
# 0       924b6a44-24bb-4640-844d-2ace5ea8f188
# 1       924b6a44-24bb-4640-844d-2ace5ea8f188
# 2       924b6a44-24bb-4640-844d-2ace5ea8f188
# 3       924b6a44-24bb-4640-844d-2ace5ea8f188
# 4       924b6a44-24bb-4640-844d-2ace5ea8f188
# ...                                      ...
# 152985  593465de-0226-4a67-8d89-320ae6bee4f6
# 152986  593465de-0226-4a67-8d89-320ae6bee4f6
# 152987  593465de-0226-4a67-8d89-320ae6bee4f6
# 152988  593465de-0226-4a67-8d89-320ae6bee4f6
# 152989  593465de-0226-4a67-8d89-320ae6bee4f6
#
#                                                  title  mileage      price
# 0                                2018 BMW X5 xDrive50i    87889     33,891
# 1                               2015 Nissan Frontier S   114543     12,941
# 2                     2014 Chevrolet Suburban 1500 LTZ   102963     20,891
# 3                        2023 Kia Sportage SX-Prestige     <NA>     34,750
# ...

# %% [raw]
# for i in range(len(cars)):
#     cars['price'][i] = cars['price'][i].replace(',', '')

# %%
cars['price'] = cars['price'].apply(lambda x: x.replace(',', ''))

# %%
cars
# Out:
#                                    dealer_id  \
# 0       924b6a44-24bb-4640-844d-2ace5ea8f188
# 1       924b6a44-24bb-4640-844d-2ace5ea8f188
# 2       924b6a44-24bb-4640-844d-2ace5ea8f188
# 3       924b6a44-24bb-4640-844d-2ace5ea8f188
# 4       924b6a44-24bb-4640-844d-2ace5ea8f188
# ...                                      ...
# 152985  593465de-0226-4a67-8d89-320ae6bee4f6
# 152986  593465de-0226-4a67-8d89-320ae6bee4f6
# 152987  593465de-0226-4a67-8d89-320ae6bee4f6
# 152988  593465de-0226-4a67-8d89-320ae6bee4f6
# 152989  593465de-0226-4a67-8d89-320ae6bee4f6
#
#                                                  title  mileage      price
# 0                                2018 BMW X5 xDrive50i    87889      33891
# 1                               2015 Nissan Frontier S   114543      12941
# 2                     2014 Chevrolet Suburban 1500 LTZ   102963      20891
# 3                        2023 Kia Sportage SX-Prestige     <NA>      34750
# ...

# %% [raw]
# for i in range(len(cars)):
#     if cars['price'][i] == 'ot Priced':
#         cars['price'][i] = float("NaN")

# %%
cars['price'].loc[cars['price'] == "ot Priced"] = float("NaN")
# Out:
# C:\Users\anabi\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
cars
# Out:
#                                    dealer_id  \
# 0       924b6a44-24bb-4640-844d-2ace5ea8f188
# 1       924b6a44-24bb-4640-844d-2ace5ea8f188
# 2       924b6a44-24bb-4640-844d-2ace5ea8f188
# 3       924b6a44-24bb-4640-844d-2ace5ea8f188
# 4       924b6a44-24bb-4640-844d-2ace5ea8f188
# ...                                      ...
# 152985  593465de-0226-4a67-8d89-320ae6bee4f6
# 152986  593465de-0226-4a67-8d89-320ae6bee4f6
# 152987  593465de-0226-4a67-8d89-320ae6bee4f6
# 152988  593465de-0226-4a67-8d89-320ae6bee4f6
# 152989  593465de-0226-4a67-8d89-320ae6bee4f6
#
#                                                  title  mileage   price
# 0                                2018 BMW X5 xDrive50i    87889   33891
# 1                               2015 Nissan Frontier S   114543   12941
# 2                     2014 Chevrolet Suburban 1500 LTZ   102963   20891
# 3                        2023 Kia Sportage SX-Prestige     <NA>   34750
# ...

# %%
#cars['price'] = cars['price'].str.strip()
cars['price'] = cars['price'].astype('float').astype('Int64')

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152990 entries, 0 to 152989
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   dealer_id  152990 non-null  object
#  1   title      152990 non-null  object
#  2   mileage    84329 non-null   Int64
#  3   price      141102 non-null  Int64
# dtypes: Int64(2), object(2)
# memory usage: 5.0+ MB

# %%
reviews['review_date'] = pd.to_datetime(reviews['review_date'], infer_datetime_format=True)

# %%
reviews
# Out:
#                                    dealer_id  review_score  \
# 0       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 1       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 2       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 3       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 4       924b6a44-24bb-4640-844d-2ace5ea8f188           2.0
# ...                                      ...           ...
# 371647  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371648  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371649  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371650  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371651  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
#
#                                              review_title review_date  \
# 0       Good place to do business with, friendly, cour...  2023-02-15
# 1                                          Happy Customer  2023-02-14
# ...

# %%
reviews['review_date'].sort_values
# Out:
# <bound method Series.sort_values of 0        2023-02-15
# 1        2023-02-14
# 2        2023-02-14
# 3        2023-02-13
# 4        2023-02-13
#             ...
# 371647   2020-01-18
# 371648   2020-01-17
# 371649   2020-01-17
# 371650   2020-01-15
# 371651   2020-01-14
# Name: review_date, Length: 371652, dtype: datetime64[ns]>

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371652 entries, 0 to 371651
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   dealer_id       371652 non-null  object
#  1   review_score    371652 non-null  float64
#  2   review_title    371645 non-null  object
#  3   review_date     371652 non-null  datetime64[ns]
#  4   review_text     371652 non-null  object
#  5   cust_service    371652 non-null  object
#  6   buying_process  371652 non-null  object
#  7   repair_quality  371652 non-null  object
#  8   facilities      371652 non-null  object
#  9   experience      371652 non-null  object
#  10  recommend       371652 non-null  object
#  11  purchase_type   371652 non-null  object
#  12  purchase        371652 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(11)
# memory usage: 36.9+ MB

# %%
reviews['cust_service'].loc[reviews['cust_service'] == "—"] = float("NaN")
reviews['buying_process'].loc[reviews['buying_process'] == "—"] = float("NaN")
reviews['repair_quality'].loc[reviews['repair_quality'] == "—"] = float("NaN")
reviews['facilities'].loc[reviews['facilities'] == "—"] = float("NaN")
reviews['experience'].loc[reviews['experience'] == "—"] = float("NaN")
# Out:
# C:\Users\anabi\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
#reviews['cust_service'] = reviews['cust_service'].str.strip()
reviews['cust_service'] = reviews['cust_service'].astype('float').astype('Int64')

# %%
#reviews['buying_process'] = reviews['buying_process'].str.strip()
reviews['buying_process'] = reviews['buying_process'].astype('float').astype('Int64')

#reviews['repair_quality'] = reviews['repair_quality'].str.strip()
reviews['repair_quality'] = reviews['repair_quality'].astype('float').astype('Int64')

#reviews['facilities'] = reviews['facilities'].str.strip()
reviews['facilities'] = reviews['facilities'].astype('float').astype('Int64')

#reviews['experience'] = reviews['experience'].str.strip()
reviews['experience'] = reviews['experience'].astype('float').astype('Int64')

# %%
reviews
# Out:
#                                    dealer_id  review_score  \
# 0       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 1       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 2       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 3       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 4       924b6a44-24bb-4640-844d-2ace5ea8f188           2.0
# ...                                      ...           ...
# 371647  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371648  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371649  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371650  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 371651  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
#
#                                              review_title review_date  \
# 0       Good place to do business with, friendly, cour...  2023-02-15
# 1                                          Happy Customer  2023-02-14
# ...

# %%
reviews.to_csv('reviews.csv', index=False)
dealers.to_csv('dealers.csv', index=False)
cars.to_csv('cars.csv', index=False)

# %%
reviews.groupby("dealer_id").mean()
# Out:
#                                       review_score  cust_service  \
# dealer_id
# 006b61d2-2bb9-4045-a005-b98ea3ae8acf      3.000000           3.0
# 00916a19-462d-4156-ab9d-b8c1471edfa0      2.963462      2.967546
# 00b48b85-f506-4a9f-86d8-66ea8d024784      4.216901      4.152542
# 00d03f8d-4fbe-419e-bc61-d39d125b91d8      3.688971      3.262136
# 00fd57ca-13b0-4872-8e40-4e691a0e45a6      4.553652       4.58125
# ...                                            ...           ...
# ff02ec6e-8764-45ae-bf2d-966d44302dcd      4.526989      4.410628
# ff09a4f1-ce1d-4793-a149-fb13572fd1d5      5.000000           5.0
# ff920ec1-8a74-4351-9305-00e2d4df4dad      4.415385      4.348837
# ffe70a26-399e-494c-9833-cc063898cb83      4.193750      4.287879
# ffeb3aa3-1998-4796-bc39-143f4106190d      4.854258      4.868651
#
#                                       buying_process  repair_quality  \
# dealer_id
# 006b61d2-2bb9-4045-a005-b98ea3ae8acf        3.133333        3.333333
# ...

# %%
reviews.groupby("dealer_id")['experience'].describe()
# Out:
#                                       count      mean       std  min  25%  \
# dealer_id
# 006b61d2-2bb9-4045-a005-b98ea3ae8acf   16.0  3.000000  2.065591  1.0  1.0
# 00916a19-462d-4156-ab9d-b8c1471edfa0  571.0  2.882662  1.951670  1.0  1.0
# 00b48b85-f506-4a9f-86d8-66ea8d024784  283.0  4.194346  1.509205  1.0  4.0
# 00d03f8d-4fbe-419e-bc61-d39d125b91d8  136.0  3.661765  1.798026  1.0  1.0
# 00fd57ca-13b0-4872-8e40-4e691a0e45a6  708.0  4.491525  1.084120  1.0  4.0
# ...                                     ...       ...       ...  ...  ...
# ff02ec6e-8764-45ae-bf2d-966d44302dcd  351.0  4.495726  1.052539  1.0  4.0
# ff09a4f1-ce1d-4793-a149-fb13572fd1d5    4.0  5.000000  0.000000  5.0  5.0
# ff920ec1-8a74-4351-9305-00e2d4df4dad   52.0  4.442308  1.258905  1.0  5.0
# ffe70a26-399e-494c-9833-cc063898cb83  144.0  4.194444  1.459369  1.0  4.0
# ffeb3aa3-1998-4796-bc39-143f4106190d  727.0  4.865199  0.637218  1.0  5.0
#
#                                       50%  75%  max
# dealer_id
# ...

# %%
cars.groupby("dealer_id")['price'].describe()
# Out:
#                                       count          mean           std  \
# dealer_id
# 003e196f-5940-4070-82b8-62f84b3c98e7   81.0  37633.506173  13700.870905
# 006b61d2-2bb9-4045-a005-b98ea3ae8acf   22.0   6276.818182   1051.364811
# 006b8bdf-8bf4-47d9-b9e0-80b0c50e2890   24.0       14220.5   5160.621171
# 00916a19-462d-4156-ab9d-b8c1471edfa0  150.0  36802.333333   8969.787843
# 00b48b85-f506-4a9f-86d8-66ea8d024784   56.0  34628.785714   8246.534712
# ...                                     ...           ...           ...
# ff02ec6e-8764-45ae-bf2d-966d44302dcd   71.0   32160.43662  12169.798695
# ff09a4f1-ce1d-4793-a149-fb13572fd1d5   34.0  87527.588235  60754.351831
# ff920ec1-8a74-4351-9305-00e2d4df4dad  111.0  37739.774775  19830.622966
# ffe70a26-399e-494c-9833-cc063898cb83  152.0  53789.144737  17927.050118
# ffeb3aa3-1998-4796-bc39-143f4106190d  208.0    34910.6875  13313.918058
#
#                                           min       25%      50%       75%  \
# dealer_id
# ...

# %%
dealers.groupby("dealer_id")['avg_rating'].describe()
# Out:
#                                       count  mean  std  min  25%  50%  75%  \
# dealer_id
# 003e196f-5940-4070-82b8-62f84b3c98e7    0.0   NaN  NaN  NaN  NaN  NaN  NaN
# 006b61d2-2bb9-4045-a005-b98ea3ae8acf    1.0   3.8  NaN  3.8  3.8  3.8  3.8
# 006b8bdf-8bf4-47d9-b9e0-80b0c50e2890    0.0   NaN  NaN  NaN  NaN  NaN  NaN
# 00916a19-462d-4156-ab9d-b8c1471edfa0    1.0   2.4  NaN  2.4  2.4  2.4  2.4
# 00b48b85-f506-4a9f-86d8-66ea8d024784    1.0   4.7  NaN  4.7  4.7  4.7  4.7
# ...                                     ...   ...  ...  ...  ...  ...  ...
# ff02ec6e-8764-45ae-bf2d-966d44302dcd    1.0   4.9  NaN  4.9  4.9  4.9  4.9
# ff09a4f1-ce1d-4793-a149-fb13572fd1d5    0.0   NaN  NaN  NaN  NaN  NaN  NaN
# ff920ec1-8a74-4351-9305-00e2d4df4dad    1.0   4.5  NaN  4.5  4.5  4.5  4.5
# ffe70a26-399e-494c-9833-cc063898cb83    1.0   4.5  NaN  4.5  4.5  4.5  4.5
# ffeb3aa3-1998-4796-bc39-143f4106190d    1.0   4.9  NaN  4.9  4.9  4.9  4.9
#
#                                       max
# dealer_id
# ...

# %% [markdown]
# Detect other languages

# %%
from spacy_language_detection import LanguageDetector
import spacy
from spacy.language import Language

# %%
import time

# %%
def get_lang_detector(nlp, name):
    return LanguageDetector()

nlp = spacy.load("en_core_web_sm")
Language.factory("language_detector", func=get_lang_detector)
nlp.add_pipe('language_detector', last=True)

# %%
text = reviews['review_text'][3548]
doc = nlp(text)
print(doc._.language)
# Out:
# {'language': 'en', 'score': 0.9999981830388182}

# %%
start_time = time.time()
lst = []
for i in range(len(reviews)):
    text = reviews['review_text'][i]
    doc = nlp(text)
    lst.append(doc._.language)

end_time = time.time()
print("time elapsed: ", end_time-start_time)
# Out:
# time elapsed:  11827.141573667526

# %%
len(lst)
# Out:
# 371652

# %%
lst[0]['language']
# Out:
# 'en'

# %%
with open(r'C:\Users\anabi\Documents\Thesis\language_list', 'w') as f:
    for i in lst:
        f.write("%s\n" % i)

# %%
with open(r'C:\Users\anabi\Documents\Thesis\language_list', 'r') as f:
    lst = f.read().splitlines()

# %%
lst
# Out:
# []
