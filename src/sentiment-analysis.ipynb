# %%
import pandas as pd
import re
import spacy
reviews = pd.read_csv("reviews_preprocessed.csv", delimiter = ',')
# Out:
# C:\Users\anabi\AppData\Roaming\Python\Python37\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
#lemmatization
reviews['reviews_text'] = reviews['review_text'].apply(lambda x: [token.lemma_ for token in nlp(x)])

# %%
#remove words with capital letters
reviews['reviews_text'] = reviews['reviews_text'].apply(lambda x: [re.sub(r'\s*[A-Z]\w*\s*', '', word) for word in x])

# %%
#remove 2-letter words
reviews['reviews_text'] = reviews['reviews_text'].apply(lambda x: [re.sub(r'\W*\b\w{1,2}\b', '', word) for word in x])

# %%
#remove empty spaces
reviews['reviews_text'] = reviews['reviews_text'].apply(lambda x: [i for i in x if i])

# %%
reviews['reviews_text']
# Out:
# 0         [good, place, business, friendly, courteous, k...
# 1         [just, purchase, new, purchase, quick, painles...
# 2           [they, friendly, helpful, year, great, service]
# 3         [salesman, extremely, nice, patient, answer, q...
# 4         [not, pleased, visit, major, concern, address,...
#                                 ...
# 370012    [great, place, purchase, vehicle, rest, team, ...
# 370013    [receive, great, customer, service, recent, pu...
# 370014    [great, even, not, buy, buy, nice, lot, give, ...
# 370015    [salesman, want, sell, helpful, like, friend, ...
# 370016    [big, thank, rest, staff, help, choose, purcha...
# Name: reviews_text, Length: 370017, dtype: object

# %% [markdown]
# Lemmatization has split the reviews into separate words, but to apply VADER, we need sentences, so we join the words back to sentences

# %% [markdown]
# Sentiment polarity

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
reviews['sentence'] = reviews['reviews_text'].apply(lambda x: ' '.join(x))

# %%
reviews['sentence']
# Out:
# 0         good place business friendly courteous knowled...
# 1         just purchase new purchase quick painless ever...
# 2                  they friendly helpful year great service
# 3         salesman extremely nice patient answer questio...
# 4         not pleased visit major concern address all it...
#                                 ...
# 370012    great place purchase vehicle rest team wonderf...
# 370013    receive great customer service recent purchase...
# 370014    great even not buy buy nice lot give treatment...
# 370015    salesman want sell helpful like friend favor t...
# 370016    big thank rest staff help choose purchase new ...
# Name: sentence, Length: 370017, dtype: object

# %%
scores = []
for sentence in reviews['sentence']:
    sid = SentimentIntensityAnalyzer()
    #print(sentence)
    ss = sid.polarity_scores(sentence)
    #for k in sorted(ss):
    scores.append(ss['compound'])
    #print(ss['compound'])
        #print('{0}: {1}, '.format(k, ss[k]), end='')
    #print()

# %%
len(scores)
# Out:
# 370017

# %%
scores
# Out:
# [0.8979,
#  0.9246,
#  0.8779,
#  0.8777,
#  -0.3412,
#  0.763,
#  0.8442,
#  0.9287,
#  0.7841,
#  0.9153,
#  0.9743,
#  0.4939,
#  0.0,
#  0.6249,
#  0.4404,
#  0.9501,
#  0.4588,
#  0.0382,
#  0.7845,
#  0.714,
#  0.5106,
#  0.0,
#  0.91,
#  0.8519,
#  0.8074,
#  0.891,
#  0.7096,
#  0.2755,
#  0.8316,
#  0.8074,
#  0.6597,
#  0.8176,
#  0.8481,
#  -0.0258,
#  0.9201,
#  0.4939,
#  0.802,
#  0.9042,
#  -0.2732,
#  0.7003,
#  0.8934,
#  0.9705,
#  -0.4763,
#  -0.6705,
#  0.9352,
#  0.6369,
#  0.9828,
#  0.9255,
#  0.978,
#  0.9509,
#  -0.4767,
#  0.8849,
#  0.765,
#  0.7351,
#  0.128,
#  0.836,
#  0.7906,
#  -0.7845,
#  -0.8161,
#  0.8519,
#  0.6908,
#  0.6249,
#  0.9081,
#  0.8126,
#  -0.1531,
#  0.6597,
#  0.7845,
#  0.4404,
#  0.8201,
#  0.7269,
#  0.6908,
#  0.9081,
#  0.765,
#  0.8689,
#  0.8834,
#  0.7783,
#  0.3975,
#  0.7171,
#  0.9666,
#  0.9216,
#  -0.4404,
#  0.7269,
#  0.8885,
#  0.8074,
#  0.891,
#  0.7845,
#  -0.0516,
#  0.7579,
#  0.6908,
#  0.4404,
#  0.7027,
#  0.6597,
#  0.7351,
#  0.5859,
#  0.6369,
#  0.8625,
#  0.8689,
#  0.4019,
#  0.9022,
#  0.9603,
#  0.8481,
#  0.9337,
#  0.8885,
#  0.8934,
#  0.9022,
#  0.3182,
#  0.8225,
#  0.9246,
#  0.8834,
#  0.8316,
#  0.7906,
#  0.9231,
#  -0.128,
#  0.7964,
#  0.3612,
#  0.6705,
#  -0.8481,
#  0.9589,
#  -0.1027,
#  -0.8934,
#  0.8775,
#  0.4588,
#  0.5719,
#  -0.6818,
#  0.542,
#  0.8908,
#  0.5965,
#  0.9062,
#  0.6369,
#  0.765,
#  0.9468,
#  0.6249,
#  -0.7774,
#  0.8658,
#  0.6801,
#  0.6249,
#  0.9081,
#  0.9062,
#  0.8481,
#  0.872,
#  -0.9325,
#  0.6249,
#  0.7579,
#  0.714,
#  0.5106,
#  -0.6705,
#  -0.7845,
#  -0.8161,
#  -0.1531,
#  0.7171,
#  0.7027,
#  -0.128,
#  -0.8481,
#  -0.8934,
#  -0.6818,
#  -0.7774,
#  -0.9325,
#  -0.6901,
#  -0.6486,
#  -0.4215,
#  -0.8591,
#  -0.6486,
#  -0.8935,
#  -0.886,
#  0.7348,
#  -0.3274,
#  -0.2773,
#  0.8916,
#  -0.1027,
#  0.8176,
#  -0.0772,
#  0.0,
#  -0.7143,
#  -0.4215,
#  -0.899,
#  -0.743,
#  0.0,
#  0.3061,
#  -0.4943,
#  0.3806,
#  -0.4456,
#  -0.4588,
#  0.0,
#  0.0,
#  0.7096,
#  -0.7707,
#  -0.9164,
#  0.1531,
#  -0.8485,
#  -0.8748,
#  -0.5853,
#  -0.8658,
#  -0.764,
#  -0.6908,
#  -0.4215,
#  -0.5574,
#  0.7119,
#  0.0,
#  -0.6597,
#  0.8074,
#  0.0,
#  -0.7099,
#  -0.5396,
#  -0.2755,
#  -0.7731,
#  0.6249,
#  -0.7096,
#  -0.6486,
#  0.6705,
#  -0.8074,
#  -0.5458,
#  0.0,
#  0.204,
#  -0.951,
#  0.0,
#  -0.25,
#  0.0772,
#  -0.4019,
#  0.0258,
#  0.4058,
#  0.7759,
#  -0.9442,
#  -0.765,
#  0.7466,
#  0.0,
#  -0.7705,
#  -0.2732,
#  -0.7003,
#  -0.743,
#  -0.0516,
#  0.0,
#  -0.3167,
#  -0.7579,
#  -0.9062,
#  0.6597,
#  -0.6927,
#  0.4588,
#  -0.4939,
#  -0.5267,
#  -0.802,
#  -0.4173,
#  -0.3875,
#  0.565,
#  -0.119,
#  -0.5293,
#  -0.34,
#  -0.6602,
#  0.802,
#  -0.088,
#  -0.5859,
#  0.7276,
#  0.8591,
#  -0.3412,
#  0.4404,
#  -0.4767,
#  0.3975,
#  -0.4404,
#  -0.0516,
#  -0.6428,
#  -0.6379,
#  0.0184,
#  -0.1341,
#  -0.3947,
#  -0.3818,
#  0.0516,
#  0.0,
#  0.34,
#  0.0,
#  -0.5729,
#  0.5859,
#  0.25,
#  -0.8264,
#  0.9667,
#  0.9432,
#  -0.7269,
#  0.9322,
#  0.7964,
#  -0.0516,
#  -0.9337,
#  -0.7346,
#  -0.0516,
#  0.7776,
#  0.8625,
#  -0.4829,
#  0.0,
#  -0.4767,
#  0.0,
#  0.565,
#  -0.9164,
#  0.9442,
#  -0.5853,
#  0.9667,
#  0.5859,
#  0.8934,
#  0.3859,
#  -0.7003,
#  -0.743,
#  0.872,
#  -0.802,
#  0.9451,
#  0.9136,
#  -0.2741,
#  0.9509,
#  0.8555,
#  0.8442,
#  0.8625,
#  0.7276,
#  -0.6602,
#  0.7408,
#  0.8591,
#  0.9423,
#  0.4201,
#  0.8979,
#  0.9246,
#  0.8779,
#  0.8777,
#  0.8442,
#  0.763,
#  -0.3412,
#  0.9287,
#  0.7841,
#  0.9153,
#  0.9743,
#  0.4939,
#  0.0,
#  0.6249,
#  0.4404,
#  0.9501,
#  0.4588,
#  0.0382,
#  0.7845,
#  0.714,
#  0.5106,
#  0.0,
#  0.91,
#  0.8519,
#  0.8074,
#  0.891,
#  0.7096,
#  0.2755,
#  0.8316,
#  0.8074,
#  0.6597,
#  0.8176,
#  0.8481,
#  -0.0258,
#  0.9201,
#  0.4939,
#  0.802,
#  0.9042,
#  -0.2732,
#  0.7003,
#  0.8934,
#  0.9705,
#  -0.4763,
#  -0.6705,
#  0.9352,
#  0.9828,
#  0.6369,
#  0.9255,
#  0.978,
#  0.9509,
#  -0.4767,
#  0.8849,
#  0.7351,
#  0.765,
#  0.836,
#  0.128,
#  0.7906,
#  -0.7845,
#  -0.8161,
#  0.8519,
#  0.6908,
#  0.6249,
#  0.9081,
#  0.8126,
#  -0.1531,
#  0.6597,
#  0.7845,
#  0.4404,
#  0.8201,
#  0.7269,
#  0.6908,
#  0.9081,
#  0.765,
#  0.8689,
#  0.8834,
#  0.7783,
#  0.3975,
#  0.7171,
#  0.9666,
#  0.9216,
#  -0.4404,
#  0.7269,
#  0.8885,
#  0.8074,
#  0.891,
#  0.7845,
#  -0.0516,
#  0.7579,
#  0.6908,
#  0.4404,
#  0.7027,
#  0.6597,
#  0.7351,
#  0.5859,
#  0.6369,
#  0.8625,
#  0.8689,
#  0.4019,
#  0.9022,
#  0.9603,
#  0.8481,
#  0.9337,
#  0.8885,
#  0.8934,
#  0.9022,
#  0.3182,
#  0.8225,
#  0.9246,
#  0.8834,
#  0.8316,
#  0.7906,
#  0.9231,
#  -0.128,
#  0.7964,
#  0.3612,
#  0.6705,
#  -0.8481,
#  0.8979,
#  0.9246,
#  0.8779,
#  0.8777,
#  0.8442,
#  0.763,
#  0.9287,
#  0.7841,
#  0.9153,
#  0.4939,
#  0.0,
#  0.6249,
#  0.9501,
#  0.7845,
#  0.0,
#  0.91,
#  0.8519,
#  0.8074,
#  0.891,
#  0.7096,
#  0.8316,
#  0.8074,
#  0.6597,
#  0.8176,
#  0.8481,
#  -0.0258,
#  0.802,
#  0.9042,
#  0.7003,
#  0.9705,
#  -0.4763,
#  0.9828,
#  0.9255,
#  0.978,
#  0.9509,
#  0.8849,
#  0.7351,
#  0.765,
#  0.836,
#  0.128,
#  0.7906,
#  0.6908,
#  0.6249,
#  0.9081,
#  0.8126,
#  0.6597,
#  0.7845,
#  0.4404,
#  0.8201,
#  0.7269,
#  0.6908,
#  0.9081,
#  0.8689,
#  0.8834,
#  0.7783,
#  0.9666,
#  0.9216,
#  0.7269,
#  0.8885,
#  0.8074,
#  0.891,
#  0.7579,
#  0.6908,
#  0.6597,
#  0.7351,
#  0.5859,
#  0.6369,
#  0.8625,
#  0.4019,
#  0.9022,
#  0.9603,
#  0.8481,
#  0.9337,
#  0.8885,
#  0.8934,
#  0.9022,
#  0.3182,
#  0.8225,
#  0.8834,
#  0.7906,
#  0.8316,
#  0.9231,
#  0.7964,
#  0.3612,
#  0.6705,
#  0.9589,
#  0.4588,
#  0.5719,
#  0.8775,
#  0.542,
#  0.8908,
#  0.5965,
#  0.9062,
#  0.6369,
#  0.765,
#  0.9468,
#  0.8658,
#  0.6801,
#  0.6249,
#  0.9081,
#  0.9062,
#  0.8481,
#  0.872,
#  0.6249,
#  0.7579,
#  0.8402,
#  0.707,
#  0.8658,
#  0.3237,
#  0.4019,
#  0.8832,
#  -0.2514,
#  0.4215,
#  -0.2311,
#  0.9042,
#  0.8779,
#  0.8979,
#  0.9442,
#  0.7579,
#  0.7506,
#  0.0258,
#  0.7717,
#  0.7845,
#  0.6369,
#  0.9371,
#  0.4939,
#  0.8625,
#  0.8957,
#  0.1531,
#  0.875,
#  0.7003,
#  0.7845,
#  0.936,
#  0.8519,
#  0.8176,
#  0.9136,
#  0.9565,
#  0.8271,
#  0.9001,
#  0.4215,
#  0.5106,
#  0.9022,
#  0.7506,
#  0.8519,
#  0.9295,
#  0.8885,
#  -0.5531,
#  0.9476,
#  0.8689,
#  0.93,
#  0.9313,
#  0.8655,
#  0.9369,
#  0.9324,
#  0.5106,
#  0.9858,
#  0.8479,
#  0.8519,
#  0.9755,
#  0.6461,
#  0.9216,
#  0.8271,
#  0.9865,
#  0.3612,
#  0.9545,
#  0.8979,
#  0.6534,
#  0.7717,
#  0.9246,
#  0.8316,
#  0.8171,
#  0.836,
#  0.9381,
#  0.9451,
#  0.946,
#  0.9371,
#  -0.296,
#  0.5719,
#  0.6597,
#  0.9153,
#  0.9274,
#  0.9657,
#  0.9259,
#  0.8779,
#  0.6486,
#  0.9337,
#  0.8617,
#  0.967,
#  0.9723,
#  0.7425,
#  0.9201,
#  0.8957,
#  0.9376,
#  0.9937,
#  0.9831,
#  0.6202,
#  0.9246,
#  0.9287,
#  0.9382,
#  0.9545,
#  0.981,
#  -0.5379,
#  0.9607,
#  0.9022,
#  0.8885,
#  0.9136,
#  0.2023,
#  0.0772,
#  0.9099,
#  0.9615,
#  0.8998,
#  0.5574,
#  0.3182,
#  0.9619,
#  0.9136,
#  0.8658,
#  0.9287,
#  0.6249,
#  0.9477,
#  0.8402,
#  0.8932,
#  0.8689,
#  0.9246,
#  0.932,
#  0.8316,
#  0.8316,
#  0.9217,
#  0.7358,
#  0.7425,
#  0.9274,
#  0.9325,
#  0.9559,
#  0.8519,
#  0.8689,
#  0.9099,
#  0.522,
#  0.296,
#  0.9678,
#  0.4019,
#  0.8966,
#  0.79,
#  0.946,
#  0.9042,
#  0.8625,
#  0.9584,
#  0.9169,
#  0.9274,
#  0.9222,
#  0.9186,
#  0.4728,
#  0.9829,
#  0.891,
#  0.9584,
#  0.8008,
#  0.908,
#  -0.128,
#  0.4201,
#  0.9582,
#  -0.2057,
#  0.6369,
#  0.7845,
#  0.886,
#  0.6901,
#  0.9606,
#  0.936,
#  0.9392,
#  0.9117,
#  0.9451,
#  0.7506,
#  0.9378,
#  0.9628,
#  0.7906,
#  0.9493,
#  0.7096,
#  0.9062,
#  0.796,
#  -0.4019,
#  0.8271,
#  0.938,
#  0.8957,
#  0.9231,
#  0.9442,
#  0.8074,
#  0.91,
#  0.9888,
#  0.9371,
#  0.9217,
#  0.8173,
#  0.9552,
#  0.8016,
#  0.946,
#  0.9201,
#  0.7523,
#  0.743,
#  0.7717,
#  -0.1027,
#  0.5574,
#  0.8176,
#  0.8519,
#  0.8271,
#  -0.4932,
#  0.8402,
#  0.9712,
#  0.9062,
#  0.9548,
#  0.7233,
#  0.8126,
#  0.9001,
#  0.8316,
#  0.9728,
#  0.4798,
#  0.0516,
#  0.9216,
#  0.8316,
#  0.8953,
#  0.2732,
#  0.836,
#  0.9628,
#  0.8807,
#  0.9001,
#  0.9451,
#  0.34,
#  0.87,
#  0.9559,
#  0.9153,
#  0.9221,
#  0.7783,
#  0.5994,
#  0.8271,
#  0.9442,
#  0.9136,
#  0.9337,
#  0.8918,
#  0.8885,
#  0.6597,
#  0.8832,
#  0.9325,
#  0.6597,
#  0.9022,
#  0.9159,
#  0.6908,
#  0.8048,
#  0.6908,
#  0.9517,
#  0.8442,
#  0.861,
#  0.8656,
#  0.8658,
#  0.9814,
#  0.9409,
#  0.8979,
#  0.945,
#  0.8787,
#  0.9763,
#  0.9423,
#  0.6705,
#  0.4939,
#  0.9042,
#  0.9657,
#  0.7755,
#  0.9171,
#  0.8777,
#  0.9169,
#  0.9031,
#  0.8519,
#  0.34,
#  0.9747,
#  0.9389,
#  0.9866,
#  0.8979,
#  0.9186,
#  0.0,
#  0.8957,
#  0.9348,
#  0.836,
#  0.967,
#  0.3612,
#  0.0,
#  0.8126,
#  0.9451,
#  0.8625,
#  0.7684,
#  0.1531,
#  0.9231,
#  0.9423,
#  0.91,
#  0.765,
#  0.9621,
#  0.8885,
#  0.9468,
#  0.8519,
#  0.9638,
#  0.2315,
#  0.9423,
#  -0.5531,
#  -0.296,
#  -0.886,
#  0.0,
#  0.9485,
#  0.8778,
#  -0.1083,
#  -0.2023,
#  0.91,
#  -0.0516,
#  -0.5423,
#  -0.6486,
#  0.427,
#  0.443,
#  0.5859,
#  -0.5574,
#  -0.4939,
#  0.7933,
#  -0.9264,
#  0.4005,
#  0.6808,
#  -0.8555,
#  0.8115,
#  0.4215,
#  0.0,
#  -0.659,
#  -0.5511,
#  0.2732,
#  0.5106,
#  -0.1027,
#  0.5574,
#  0.607,
#  -0.1027,
#  0.0826,
#  -0.7591,
#  -0.3818,
#  0.0,
#  -0.7269,
#  -0.9368,
#  0.8173,
#  0.0772,
#  0.8481,
#  -0.1531,
#  0.3572,
#  0.8402,
#  0.4653,
#  -0.1027,
#  0.0177,
#  0.5542,
#  0.1779,
#  0.0516,
#  0.8225,
#  0.6486,
#  0.9349,
#  0.6124,
#  0.9349,
#  0.9169,
#  0.9451,
#  0.7506,
#  0.8718,
#  -0.4822,
#  0.8176,
#  0.8688,
#  0.7506,
#  0.9169,
#  0.9524,
#  0.4019,
#  0.9022,
#  0.9402,
#  0.8225,
#  0.9101,
#  0.9186,
#  0.8519,
#  0.9274,
#  0.3182,
#  0.9559,
#  0.6705,
#  0.34,
#  0.7269,
#  0.1531,
#  0.4215,
#  0.8251,
#  0.8807,
#  0.9313,
#  0.7841,
#  0.8074,
#  0.9169,
#  0.8008,
#  0.6124,
#  0.3182,
#  0.8979,
#  0.836,
#  0.9226,
#  0.3612,
#  0.8658,
#  0.891,
#  0.9312,
#  0.8481,
#  0.8779,
#  0.0516,
#  0.8481,
#  0.6908,
#  0.5423,
#  0.4404,
#  0.9423,
#  0.9544,
#  0.9403,
#  0.765,
#  0.7328,
#  0.9403,
#  0.9559,
#  0.891,
#  0.875,
#  0.6249,
#  0.8834,
#  0.7783,
#  0.8805,
#  0.2665,
#  0.0,
#  0.4404,
#  0.8055,
#  0.9382,
#  0.9246,
#  0.8519,
#  0.9493,
#  0.9201,
#  0.9403,
#  0.8481,
#  0.9259,
#  0.6249,
#  0.7331,
#  0.9612,
#  0.8126,
#  0.9577,
#  0.9186,
#  0.8689,
#  0.7906,
#  0.6597,
#  0.8779,
#  -0.9491,
#  0.946,
#  0.836,
#  0.946,
#  0.9258,
#  0.875,
#  0.8122,
#  0.9578,
#  0.8519,
#  0.9295,
#  0.8885,
#  0.9476,
#  0.8689,
#  0.93,
#  0.9313,
#  0.8655,
#  0.9369,
#  0.9324,
#  0.9858,
#  0.8479,
#  0.8519,
#  0.9755,
#  0.6461,
#  0.9216,
#  0.8271,
#  0.9865,
#  0.3612,
#  0.9545,
#  0.8979,
#  0.6534,
#  0.7717,
#  0.9246,
#  0.8316,
#  0.8171,
#  0.836,
#  0.9381,
#  0.9451,
#  0.946,
#  ...]

# %%
reviews['sentiment_score'] = scores

# %%
reviews
# Out:
#                                    dealer_id  review_score  \
# 0       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 1       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 2       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 3       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0
# 4       924b6a44-24bb-4640-844d-2ace5ea8f188           2.0
# ...                                      ...           ...
# 370012  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 370013  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 370014  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 370015  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
# 370016  593465de-0226-4a67-8d89-320ae6bee4f6           5.0
#
#                                              review_title review_date  \
# 0       Good place to do business with, friendly, cour...  2023-02-15
# 1                                          Happy Customer  2023-02-14
# 2             They have always been friendly and helpful.  2023-02-14
# 3                                  My salesman was Ghina!  2023-02-13
# 4                                 Not pleased this visit.  2023-02-13
# ...                                                   ...         ...
# 370012  Mercedes of Loveland was a great place to purc...  2020-01-18
# 370013  We received great customer service during the ...  2020-01-17
# 370014  Ken was great! Even though I didn’t buy a Merc...  2020-01-17
# 370015                                   Great experience  2020-01-15
# 370016  A big thank you to Carlos and the rest of the ...  2020-01-14
#
#                                               review_text  cust_service  \
# 0       Good place business friendly courteous knowled...           NaN
# 1       Just purchased new Telluride James Myrick purc...           NaN
# 2           They friendly helpful Ive years great service           NaN
# 3       My salesman Ghina He extremely nice patient an...           NaN
# 4       Not pleased visit Major concern addressed All ...           NaN
# ...                                                   ...           ...
# 370012  Mercedes Loveland great place purchase vehicle...           NaN
# 370013  We received great customer service recent purc...           NaN
# 370014  Ken great Even I didnt buy Mercedes I bought n...           NaN
# 370015  My salesman want sell He helpful like friend f...           5.0
# 370016  A big thank Carlos rest staff Mercedes Lovelan...           NaN
#
#         buying_process  repair_quality  facilities  experience recommend  \
# 0                  NaN             NaN         NaN         5.0       yes
# 1                  5.0             NaN         5.0         5.0       yes
# 2                  NaN             NaN         NaN         5.0       yes
# 3                  NaN             NaN         NaN         5.0       yes
# 4                  NaN             NaN         NaN         2.0        no
# ...                ...             ...         ...         ...       ...
# 370012             NaN             NaN         NaN         5.0       yes
# 370013             NaN             NaN         NaN         5.0       yes
# 370014             NaN             NaN         NaN         5.0       yes
# 370015             5.0             NaN         NaN         5.0       yes
# 370016             NaN             NaN         NaN         5.0       yes
#
#        purchase_type     purchase  \
# 0                new  no purchase
# 1                new          yes
# 2             repair  no purchase
# 3               used  no purchase
# 4             repair  no purchase
# ...              ...          ...
# 370012          used  no purchase
# 370013           new  no purchase
# 370014          used  no purchase
# 370015          used          yes
# 370016           new  no purchase
#
#                                              reviews_text  \
# 0       [good, place, business, friendly, courteous, k...
# 1       [just, purchase, new, purchase, quick, painles...
# 2         [they, friendly, helpful, year, great, service]
# 3       [salesman, extremely, nice, patient, answer, q...
# 4       [not, pleased, visit, major, concern, address,...
# ...                                                   ...
# 370012  [great, place, purchase, vehicle, rest, team, ...
# 370013  [receive, great, customer, service, recent, pu...
# 370014  [great, even, not, buy, buy, nice, lot, give, ...
# 370015  [salesman, want, sell, helpful, like, friend, ...
# 370016  [big, thank, rest, staff, help, choose, purcha...
#
#                                                  sentence  sentiment_score
# 0       good place business friendly courteous knowled...           0.8979
# 1       just purchase new purchase quick painless ever...           0.9246
# 2                they friendly helpful year great service           0.8779
# 3       salesman extremely nice patient answer questio...           0.8777
# 4       not pleased visit major concern address all it...          -0.3412
# ...                                                   ...              ...
# 370012  great place purchase vehicle rest team wonderf...           0.9442
# 370013  receive great customer service recent purchase...           0.7269
# 370014  great even not buy buy nice lot give treatment...           0.7998
# 370015  salesman want sell helpful like friend favor t...           0.9349
# 370016  big thank rest staff help choose purchase new ...           0.8225
#
# [370017 rows x 16 columns]

# %%
#take only relevant columns
analysis_dataset = reviews[['dealer_id', 'review_score', 'cust_service', 'buying_process', 
                            'repair_quality', 'facilities', 'experience', 'recommend', 'purchase_type',
                            'purchase', 'sentiment_score']].copy()

# %%
analysis_dataset
# Out:
#                                    dealer_id  review_score  cust_service  \
# 0       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0           NaN
# 1       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0           NaN
# 2       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0           NaN
# 3       924b6a44-24bb-4640-844d-2ace5ea8f188           5.0           NaN
# 4       924b6a44-24bb-4640-844d-2ace5ea8f188           2.0           NaN
# ...                                      ...           ...           ...
# 370012  593465de-0226-4a67-8d89-320ae6bee4f6           5.0           NaN
# 370013  593465de-0226-4a67-8d89-320ae6bee4f6           5.0           NaN
# 370014  593465de-0226-4a67-8d89-320ae6bee4f6           5.0           NaN
# 370015  593465de-0226-4a67-8d89-320ae6bee4f6           5.0           5.0
# 370016  593465de-0226-4a67-8d89-320ae6bee4f6           5.0           NaN
#
#         buying_process  repair_quality  facilities  experience recommend  \
# 0                  NaN             NaN         NaN         5.0       yes
# 1                  5.0             NaN         5.0         5.0       yes
# 2                  NaN             NaN         NaN         5.0       yes
# 3                  NaN             NaN         NaN         5.0       yes
# 4                  NaN             NaN         NaN         2.0        no
# ...                ...             ...         ...         ...       ...
# 370012             NaN             NaN         NaN         5.0       yes
# 370013             NaN             NaN         NaN         5.0       yes
# 370014             NaN             NaN         NaN         5.0       yes
# 370015             5.0             NaN         NaN         5.0       yes
# 370016             NaN             NaN         NaN         5.0       yes
#
#        purchase_type     purchase  sentiment_score
# 0                new  no purchase           0.8979
# 1                new          yes           0.9246
# 2             repair  no purchase           0.8779
# 3               used  no purchase           0.8777
# 4             repair  no purchase          -0.3412
# ...              ...          ...              ...
# 370012          used  no purchase           0.9442
# 370013           new  no purchase           0.7269
# 370014          used  no purchase           0.7998
# 370015          used          yes           0.9349
# 370016           new  no purchase           0.8225
#
# [370017 rows x 11 columns]

# %%
analysis_dataset.to_csv("analysis_dataset.csv", index=False)

# %%
reviews.to_csv("reviews_preprocessed.csv", index=False)

# %%
#save sentiment scores separately
with open('sentiment_scores.txt', 'w+') as f:
    # write elements of list
    for items in scores:
        f.write('%s\n' %items)
       
    
f.close()

# %% [raw]
# file = []
# with open ('sentiment_scores.txt', 'r') as f:
#     for x in f.readlines():
#         file.append(float(x.strip('\n')))
